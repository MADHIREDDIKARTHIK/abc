# %% [markdown]
# <a href="https://colab.research.google.com/github/MADHIREDDIKARTHIK/abc/blob/main/ml%20exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv("/content/netflix_revenue_updated.csv")
data
# Out:
#           Date  Global Revenue  UCAN Streaming Revenue  \
# 0   31-03-2019      4520992000              2256851000
# 1   30-06-2019      4923116000              2501199000
# 2   30-09-2019      5244905000              2621250000
# 3   31-12-2019      5467434000              2671908000
# 4   31-03-2020      5767691000              2702776000
# 5   30-06-2020      6148286000              2839670000
# 6   30-09-2020      6435637000              2933445000
# 7   31-12-2020      6644442000              2979505000
# 8   31-03-2021      7163282000              3170972000
# 9   30-06-2021      7341777000              3234643000
# 10  30-09-2021      7483467000              3257697000
# 11  31-12-2021      7709318000              3308788000
# 12  31-03-2022      7867767000              3350424000
# 13  30-06-2022      7970141000              3537863000
# 14  30-09-2022      7925589000              3601565000
# 15  31-12-2022      7852053000              3594791000
# ...

# %%
concepts=np.array(data)[:,:-1]
concepts
# Out:
# array([['31-03-2019', 4520992000, 2256851000, 1233379000, 630472000,
#         319602000, 66633000, 42542000, 27547000, 12141000, 11.45, 10.23,
#         7.84, 9.37],
#        ['30-06-2019', 4923116000, 2501199000, 1319087000, 677136000,
#         349494000, 66501000, 44229000, 27890000, 12942000, 12.52, 10.13,
#         8.14, 9.29],
#        ['30-09-2019', 5244905000, 2621250000, 1428040000, 741434000,
#         382304000, 67114000, 47355000, 29380000, 14485000, 13.08, 10.4,
#         8.63, 9.29],
#        ['31-12-2019', 5467434000, 2671908000, 1562561000, 746392000,
#         418121000, 67662000, 51778000, 31417000, 16233000, 13.22, 10.51,
#         8.18, 9.07],
#        ['31-03-2020', 5767691000, 2702776000, 1723474000, 793453000,
#         483660000, 69969000, 58734000, 34318000, 19835000, 13.09, 10.4,
#         8.05, 8.94],
#        ['30-06-2020', 6148286000, 2839670000, 1892537000, 785368000,
#         569140000, 72904000, 61483000, 36068000, 22492000, 13.25, 10.5,
# ...

# %%
target=np.array(data)[:,-1]
target
# Out:
# array([148863000, 151562000, 158334000, 167090000, 182856000, 192947000,
#        195151000, 203663000, 207639000, 209180000, 213563000, 221844000,
#        221641000, 220672000, 223085000, 230747000, 232498000, 238390000,
#        247153000, 260276000, 269602000], dtype=object)

# %%
def train(con,tar):
  for i,val in enumerate(tar):
    if val=='yes':
      specific_h=con[i].copy()
      break
  for i,val in enumerate(con):
    if tar[i]=='yes':
      for x in range(len(specific_h)):
        if val[x]!=specific_h[x]:
          specific_h[x]='?'
        else:
          pass
      return specific_h
print("n The final hypothesis is:",train(data,target))
# Out:
# n The final hypothesis is: None

# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv("/content/data.csv")
data
# Out:
#      sky air temp humidity    wind water forecast enjoy sport
# 0  sunny     warm   normal  strong  warm     same         yes
# 1  sunny     warm     high  strong  warm     same         yes
# 2  rainy     cold     high  strong  warm   change          no
# 3  sunny     warm     high  strong  cool   change         yes

# %%
concepts=np.array(data)[:,-1]
concepts
# Out:
# array(['yes', 'yes', 'no', 'yes'], dtype=object)

# %%
target=np.array(data)[:,-1]
target
# Out:
# array(['yes', 'yes', 'no', 'yes'], dtype=object)

# %%
def train(con,tar):
  for i,val in enumerate(tar):
    if val=='yes':
      specific_h=con[i].copy() # Access numpy array using integer indexing
      break
  for i,val in enumerate(con):
    if tar[i]=='yes':
      for x in range(len(specific_h)):
        if val[x]!=specific_h[x]:
          specific_h[x]='?'
        else:
          pass
      return specific_h

# %%
print("n The final hypothesis is:",train(concepts,target))
# Out:
# n The final hypothesis is: ['sunny' 'warm' 'normal' 'strong' 'warm' 'same']
